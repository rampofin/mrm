# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import sklearn as sl
import seaborn as sns

# %%
df = pd.read_csv('train_data.csv')
df
# Out:
#       id   Age Sex Health_Index Fat_Level  Mineral_Ratio  Treatment_Type
# 0      1  36.0   M          LOW    NORMAL         11.424               4
# 1      2  16.0   F         HIGH    NORMAL         15.516               0
# 2      3  18.0   F       NORMAL    NORMAL          8.750               4
# 3      4  59.0   F          LOW      HIGH         10.444               3
# 4      5  47.0   M          LOW    NORMAL         18.043               0
# ..   ...   ...  ..          ...       ...            ...             ...
# 155  156  34.0   M         HIGH      HIGH         18.703               0
# 156  157  45.0   M          LOW    NORMAL         10.017               4
# 157  158  52.0   M          LOW    NORMAL         32.922               0
# 158  159  43.0   M         HIGH      HIGH         13.972               1
# 159  160  24.0   F          LOW      HIGH         10.605               4
#
# [160 rows x 7 columns]

# %%
#locating null values
df.loc[:].isna().sum()
# Out:
# id                0
# Age               0
# Sex               0
# Health_Index      0
# Fat_Level         0
# Mineral_Ratio     0
# Treatment_Type    0
# dtype: int64

# %%
#total columns and rows
print("columns = ",len(df.columns))
print("rows = ",len(df.index))
#pretty small data set so we gonna cap the data outliers
# Out:
# columns =  7
# rows =  160

# %%
#sex and treatment type are not really correlated as p value = 0.8 which is > 0.05 significance level
#Health_Index is highly correlated to treatment as p value <<< 0.05 significance level
#Fat_Level might be somewhat correlated to treatment type as p value is around 0.05. 
        #To prevent underfit we will consider it.

# %%
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder

# Encode categorical variables
encoder = LabelEncoder()
df['Sex'] = encoder.fit_transform(df['Sex'])
df['Health_Index'] = encoder.fit_transform(df['Health_Index'])
df['Fat_Level'] = encoder.fit_transform(df['Fat_Level'])

X = df[['Sex', 'Health_Index', 'Fat_Level']]
y = df['Treatment_Type']

correlation = df[['Age','Mineral_Ratio','Fat_Level','Treatment_Type']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
pl.show()


chi_scores = chi2(X, y)
print(chi_scores)
# Out:
# (array([ 1.30146166, 52.9337773 ,  7.62212913]), array([8.61127490e-01, 8.79803679e-11, 1.06442943e-01]))

# %%
#considering columns will be Mineral_Ratio, Health_Index and Fat_Level for prediction
refinedData = df[['Mineral_Ratio','Health_Index','Treatment_Type']]
IQR = refinedData.describe()
IQR
# Out:
#        Mineral_Ratio  Health_Index  Treatment_Type
# count     160.000000    160.000000      160.000000
# mean       15.778800      0.906250        1.600000
# std         6.886081      0.822612        1.694237
# min         6.269000      0.000000        0.000000
# 25%        10.565250      0.000000        0.000000
# 50%        13.826500      1.000000        1.000000
# 75%        19.048500      2.000000        4.000000
# max        38.247000      2.000000        4.000000

# %%
IQR_Range = IQR.loc['75%','Mineral_Ratio'] - IQR.loc['25%','Mineral_Ratio']
lower_1 = IQR.loc['25%','Mineral_Ratio'] - (1.5*IQR_Range)
upper_1 = IQR.loc['75%','Mineral_Ratio'] + (1.5*IQR_Range)
refinedData = refinedData[(refinedData['Mineral_Ratio'] >= lower_1) & (refinedData['Mineral_Ratio'] <= upper_1)]
refinedData
# Out:
#      Mineral_Ratio  Health_Index  Treatment_Type
# 0           11.424             1               4
# 1           15.516             0               0
# 2            8.750             2               4
# 3           10.444             1               3
# 4           18.043             1               0
# ..             ...           ...             ...
# 154         20.942             1               0
# 155         18.703             0               0
# 156         10.017             1               4
# 158         13.972             0               1
# 159         10.605             1               4
#
# [154 rows x 3 columns]

# %%
#normalization of numerical data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
refinedData['Mineral_Ratio'] = scaler.fit_transform(refinedData[['Mineral_Ratio']])
refinedData
# Out:
#      Mineral_Ratio  Health_Index  Treatment_Type
# 0         0.213927             1               4
# 1         0.383741             0               0
# 2         0.102959             2               4
# 3         0.173258             1               3
# 4         0.488609             1               0
# ..             ...           ...             ...
# 154       0.608914             1               0
# 155       0.515998             0               0
# 156       0.155538             1               4
# 158       0.319666             0               1
# 159       0.179939             1               4
#
# [154 rows x 3 columns]

# %%
from sklearn.cluster import KMeans

X = refinedData[['Mineral_Ratio','Health_Index']]
inertia = []
k_range = range(1, 11)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)  # Inertia: Sum of squared distances to closest cluster center

# Plot the elbow curve
pl.figure(figsize=(10, 6))
pl.plot(k_range, inertia, marker='o')
pl.title('Elbow Method for Optimal k')
pl.xlabel('Number of Clusters (k)')
pl.ylabel('Inertia')
pl.xticks(k_range)
pl.grid()
pl.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Fit K-Means with the chosen number of clusters
k = 4  # Replace with the optimal k you found
kmeans = KMeans(n_clusters=k, random_state=42)
refinedData['Cluster'] = kmeans.fit_predict(X)  # Adds the cluster assignment to your DataFrame

# Check the resulting DataFrame with cluster assignments
print(refinedData.head())
# Out:
#    Mineral_Ratio  Health_Index  Treatment_Type  Cluster
# 0       0.213927             1               4        2
# 1       0.383741             0               0        3
# 2       0.102959             2               4        0
# 3       0.173258             1               3        2
# 4       0.488609             1               0        2
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# from sklearn.metrics import accuracy_score

# y_pred_val = best_model.predict(X_val)
# print(f"Validation Accuracy: {accuracy_score(y_val, y_pred_val)}")
from mpl_toolkits.mplot3d import Axes3D
fig = pl.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(refinedData['Mineral_Ratio'], 
           refinedData['Health_Index'].astype('category').cat.codes,  # Convert categorical to numerical for plotting
           # Convert categorical to numerical for plotting
           c=refinedData['Cluster'], 
           cmap='viridis', 
           marker='o')

# Set labels
ax.set_xlabel('Mineral Ratio (Normalized)')
ax.set_ylabel('Health Index (Encoded)')
ax.set_zlabel('Fat Level (Encoded)')
ax.set_title('K-Means Clustering in 3D Space')

# Show color bar
pl.colorbar(ax.collections[0], label='Cluster')
pl.show()

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, fowlkes_mallows_score

# %%
# Apply PCA to reduce dimensions to 2 components for visualization
pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(refinedData.drop(columns=['Treatment_Type']))  # Drop the label column

# Visualize PCA-transformed data
pl.scatter(pca_transformed[:, 0], pca_transformed[:, 1], s=50)
pl.title('PCA - 2D Projection of Data')
pl.show()

# %%
# Initialize K-Means with k-means++ to improve cluster initialization
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42)
kmeans.fit(pca_transformed)   

# Predict clusters
refinedData['Cluster'] = kmeans.labels_

# Evaluate the clustering using Silhouette Score (closer to 1 is better)
silhouette_avg = silhouette_score(pca_transformed, kmeans.labels_)
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.9584449405301747
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# now working on testing data
df_test = pd.read_csv('test_data.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
# Manually map 'M' and 'F' in test data to match training encoding
df_test['Sex'] = df_test['Sex'].map({'Male': 0, 'Female': 1})

# %%
# Check unique categories in training
known_health_index = ['HIGH', 'MEDIUM', 'LOW']  # Replacing with actual categories seen in training
df_test['Health_Index'] = df_test['Health_Index'].apply(lambda x: x if x in known_health_index else 'LOW')

# Encode Health_Index and Fat_Level by using same encoder as i did in training
encoder = LabelEncoder()
encoder.fit(['HIGH', 'MEDIUM', 'LOW'])  # Assuming these were same labels in training data

df_test['Health_Index'] = encoder.transform(df_test['Health_Index'])

# Handle Fat_Level similarly
known_fat_level = ['HIGH', 'LOW']  # Replacing with actual categories seen in training
df_test['Fat_Level'] = df_test['Fat_Level'].apply(lambda x: x if x in known_fat_level else 'LOW')

encoder.fit(['HIGH', 'LOW'])
df_test['Fat_Level'] = encoder.transform(df_test['Fat_Level'])

# %%
# Normalize the Mineral_Ratio column
scaler = MinMaxScaler()
df_test['Mineral_Ratio'] = scaler.fit_transform(df_test[['Mineral_Ratio']])

# %%
#  rest of our processing and predictions
X_test = df_test[['Mineral_Ratio', 'Health_Index', 'Fat_Level']]
#  K-Means on test data
k = 4  #let
kmeans_test = KMeans(n_clusters=k, random_state=42)
df_test['Cluster'] = kmeans_test.fit_predict(X_test)
silhouette_avg_test = silhouette_score(X_test, kmeans_test.labels_)
print(f'Test Data Silhouette Score: {silhouette_avg_test}')
pca = PCA(n_components=2)  # Reduce to 2 dimensions 
X_test_pca = pca.fit_transform(X_test)
# Out:
# Test Data Silhouette Score: 0.7472047256767258
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Tuning no. of clusters (k)
best_k = None
best_silhouette = -1
k_range = range(2, 11)  # Trying different values for k
for k in k_range:
    kmeans_test = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans_test.fit_predict(X_test_pca)
    
    silhouette_avg = silhouette_score(X_test_pca, cluster_labels)
    print(f'Silhouette Score for k={k}: {silhouette_avg}')
    
    # Track the best silhouette score
    if silhouette_avg > best_silhouette:
        best_silhouette = silhouette_avg
        best_k = k

print(f'Best k: {best_k}, Best Silhouette Score: {best_silhouette}')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Silhouette Score for k=2: 0.6197764072545553
# Silhouette Score for k=3: 0.7698170146111548
# Silhouette Score for k=4: 0.9097360662636795
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Silhouette Score for k=5: 0.7611036575214694
# Silhouette Score for k=6: 0.7063427170613029
# Silhouette Score for k=7: 0.6593039113807537
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Silhouette Score for k=8: 0.6062811824183579
# Silhouette Score for k=9: 0.5724938890170576
# Silhouette Score for k=10: 0.5748744398434021
# Best k: 4, Best Silhouette Score: 0.9097360662636795
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Final model with the best k
kmeans_test_final = KMeans(n_clusters=best_k, random_state=42)
df_test['Cluster'] = kmeans_test_final.fit_predict(X_test_pca)

# Final Silhouette Score for test data with optimal k
final_silhouette_score = silhouette_score(X_test_pca, kmeans_test_final.labels_)
print(f'Final Test Data Silhouette Score: {final_silhouette_score}')
# Out:
# Final Test Data Silhouette Score: 0.9097360662636795
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
